# %%
import pandas as pd

# %%
data = [1,2,3,4,5]
series = pd.Series(data)
print("Series\n" , series)
# Out:
# Series
#  0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
# Series from Dictianary
data = {'a':1,'b':2,'c':3}
seris_dict = pd.Series(data)
print("Series_Dict\n",seris_dict)
# Out:
# Series_Dict
#  a    1
# b    2
# c    3
# dtype: int64

# %%
# Create A DataFrame form Dictanary of list

data ={
    'Name':['Hetal','Shreya','Anushka'],
    'Age':[20 , 21, 22],
    'City':['Dhule','Satara','Nagar']
}
df = pd.DataFrame(data)
print(df)
print(type(df))
# Out:
#       Name  Age    City
# 0    Hetal   20   Dhule
# 1   Shreya   21  Satara
# 2  Anushka   22   Nagar
# <class 'pandas.core.frame.DataFrame'>

# %%
df
# Out:
#       Name  Age    City
# 0    Hetal   20   Dhule
# 1   Shreya   21  Satara
# 2  Anushka   22   Nagar

# %%
df.loc[0]
# Out:
# Name    Hetal
# Age        20
# City    Dhule
# Name: 0, dtype: object

# %%
df.iloc[0][0]
# Out:
# C:\Users\hetal\AppData\Local\Temp\ipykernel_23944\2900375399.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.iloc[0][0]
# 'Hetal'

# %%
# Accessing the Specified Element
df.at[1 ,'Name']
# Out:
# 'Shreya'

# %%
df.iat[2,2]
# Out:
# 'Nagar'

# %%
df
# Out:
#       Name  Age    City
# 0    Hetal   20   Dhule
# 1   Shreya   21  Satara
# 2  Anushka   22   Nagar

# %%
# Data Manipulation in Dataframe
df
# Out:
#       Name  Age    City
# 0    Hetal   20   Dhule
# 1   Shreya   21  Satara
# 2  Anushka   22   Nagar

# %%
# Adding New Coloumn of Salary
df['Salary'] = [50000, 60000, 700000]
df
# Out:
#       Name  Age    City  Salary
# 0    Hetal   20   Dhule   50000
# 1   Shreya   21  Satara   60000
# 2  Anushka   22   Nagar  700000

# %%
# Create A DataFrame form Dictanary of list
import pandas as pd
data ={
    'Name':['Hetal','Shreya','Anushka'],
    'Age':[20 , 21, 22],
    'City':['Dhule','Satara','Nagar'],
    'Salary' : [50000,60000,70000]
}
df = pd.DataFrame(data)
print(df)
print(type(df))
# Out:
#       Name  Age    City  Salary
# 0    Hetal   20   Dhule   50000
# 1   Shreya   21  Satara   60000
# 2  Anushka   22   Nagar   70000
# <class 'pandas.core.frame.DataFrame'>

# %%
df.drop('Salary',axis=1 , inplace=True)
df
# Out:
#       Name  Age    City
# 0    Hetal   20   Dhule
# 1   Shreya   21  Satara
# 2  Anushka   22   Nagar

# %%
print(list(df.columns))
# Out:
# ['Name', 'Age', 'City']

# %%
df
# Out:
#       Name  Age    City
# 0    Hetal   20   Dhule
# 1   Shreya   21  Satara
# 2  Anushka   22   Nagar

# %%
df
# Out:
#       Name  Age    City
# 0    Hetal   20   Dhule
# 1   Shreya   21  Satara
# 2  Anushka   22   Nagar

# %%
df['Age']=df['Age']-1
df
# Out:
#       Name  Age    City
# 0    Hetal   19   Dhule
# 1   Shreya   20  Satara
# 2  Anushka   21   Nagar
